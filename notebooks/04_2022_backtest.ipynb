# %%
import pandas as pd
df = pd.read_csv('../data/processed/updated_model_dataset.csv')
df
# Out:
# c:\Users\yuval\anaconda3\Lib\site-packages\pandas\core\computation\expressions.py:23: UserWarning: Pandas requires version '2.10.2' or newer of 'numexpr' (version '2.8.4' currently installed).
#   from pandas.core.computation.check import NUMEXPR_INSTALLED
# c:\Users\yuval\anaconda3\Lib\site-packages\pandas\core\arrays\masked.py:56: UserWarning: Pandas requires version '1.4.2' or newer of 'bottleneck' (version '1.3.5' currently installed).
#   from pandas.core import (
#              date         team_a                team_b  \
# 0      2004-01-01        Bermuda              Barbados
# 1      2004-01-01         Kuwait                 Yemen
# 2      2004-01-01   Saudi Arabia               Bahrain
# 3      2004-01-03        Bahrain                  Oman
# 4      2004-01-03          Qatar  United Arab Emirates
# ...           ...            ...                   ...
# 21650  2026-06-07  Liechtenstein                Cyprus
# 21651  2026-06-07        Morocco                Norway
# ...

# %%
df_later = df[df['date'] >= '2018-01-01']
df_later = df_later[df_later['date'] <= '2022-12-31']
df_later
